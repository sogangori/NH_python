# %%
import pandas as pd
import numpy as np

# %%
df0 = pd.read_csv('^DJI.csv')
df1 = pd.read_csv('^DJI (1).csv')
df0.shape, df1.shape
# Out:
# ((251, 7), (251, 7))

# %%
arr0 = np.array(df0)
arr1 = np.array(df1)

# %%
arr = np.concatenate((arr0, arr1), axis=0)
arr.shape
# Out:
# (502, 7)

# %%
arr[0]
# Out:
# array(['2018-06-18', 24944.279297, 25003.099609, 24825.769531,
#        24987.470703, 24987.470703, 337070000], dtype=object)

# %% [markdown]
# - 각 컬럼의 평균값을 구합니다
# - 가격 변동(Close-Open)이 가장 큰 때가 언제인지(날짜)를 알고 싶다.

# %%
np.mean(arr[:, 1:], axis=0).astype(np.int) #날짜 빼주세요
# Out:
# array([    24525,     24642,     24399,     24527,     24527, 332232888])

# %%
Close = arr[:,4]
Open =  arr[:,1]
Gap = np.abs(Close - Open) #절대값을 구하세요. 아니면 가격이 가장 많이 상승한 날이 조회됩니다
index = np.argmax(Gap) #변동이 가장 큰 행번호
np.max(Gap), (Close - Open)[index], arr[index, 0] #변동이 가장 큰 행의 날짜 정보
# Out:
# (1041.8398430000016, -1041.8398430000016, '2018-02-08')

# %% [markdown]
# 중국 미국 무역전쟁으로 2018년 2월 2일부터 전세계 주가가 20%이상 폭락했고 다우지수는 133년 중 최대 낙폭 기록

# %% [markdown]
# 주가와 거래량을 그래프로 표현해보세요

# %%
Open =  arr[:,1]
High =  arr[:,2]
Low =  arr[:,3]
Close = arr[:,4]
Vol = arr[:,-1]

# %%
plt.figure(figsize=(40,10))# 인치(width, height)
plt.plot(Open, linestyle='--', label='open')
plt.plot(High,  label='high')
plt.plot(Low, 'r.', label='low')
plt.plot(Close,  label='close')
plt.legend()
plt.title('Dow Jones Industrial Average')
# Out:
# Text(0.5, 1.0, 'Dow Jones Industrial Average')

# %%
plt.plot(Vol)

# %% [markdown]
# ## 4장 기본 그래프 그리기 p55

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10,20,30,40]) # Y
#plt.show() # print 안해도 출력되듯이 show() 하지 않아도 그려집니다

# %%
#그림을 이 문서 안에 그려라
# %matplotlib inline

# %%
# 한 셀에서 여러번 plot 하면 그래프가 겹쳐집니다
plt.plot([1,2,3,4],[12,43,25,15],'r.', label='A') #마커모양을 바꾸면 점으로 표현
plt.plot([1,2,3,4],[20,44,55,10],label='B', color='red', linestyle=':')
plt.plot([1,5,10,60],'g^', label='C', linestyle='--')
plt.legend(loc=4)#범례 그려라 p61
plt.title('Graph title')
# Out:
# Text(0.5, 1.0, 'Graph title')
